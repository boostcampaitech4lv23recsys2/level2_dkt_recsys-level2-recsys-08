# %% [markdown]
# ## dataLoad

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
import pandas as pd
import os
import random
import warnings
warnings.filterwarnings('ignore')
import lightgbm as lgb
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
import numpy as np
from utils import custom_train_test_split, lgbm_predict, post_slack
base_feats = ['KnowledgeTag', 'user_correct_answer', 'user_total_answer', 
         'user_acc', 'test_mean', 'test_sum', 'tag_mean','tag_sum']
# train과 test 데이터셋은 사용자 별로 묶어서 분리를 해주어야함

## 1. 데이터 로딩
data_dir = '/opt/ml/input/data' # 경로
# train_file_path = os.path.join(data_dir, 'train_data.csv') # 데이터
# test_file_path = os.path.join(data_dir, 'test_data.csv')
after_fe_path = os.path.join(data_dir, 'after_fe_train_test.pkl')
df = pd.read_pickle(after_fe_path)

train_df = df[df.kind=='train']

# %%
train, valid = custom_train_test_split(train_df, ratio=0.7, seed=13) # 훈련데이터 split
test = df[df.kind=='test'] # 테스트 데이터
train2 = test[test.answerCode!=-1] # 테스트데이터 마지막 제출 2번쨰꺼까지 훈련데이터로 사용
train = pd.concat([train_df,train2]) # 훈련데이터 병합
train.shape, valid.shape, test.shape

x_train = train.drop('answerCode',axis=1)
y_train = train[['answerCode']]

x_valid = valid.drop('answerCode',axis=1)
y_valid = valid[['answerCode']]
x_train.shape, y_train.shape, x_valid.shape, y_valid.shape
# Out:
# ((2525956, 26), (1974, 26), (260114, 26))
# ((2525956, 25), (2525956, 1), (1974, 25), (1974, 1))

# %%
def custom_train_test_split(df, ratio=0.7, seed=41, split=True):
    """df를 입력받아서, userid들을 랜덤해서 1-ratio만큼의 user만 선별하고, 마지막 제출껀만 만들어서 train, test로 리턴 """
    random.seed(seed)
    ## (user_id, 문제푼 횟수)를 원소로 갖는 리스트
    users = list(zip(df['userID'].value_counts().index, df['userID'].value_counts()))
    random.shuffle(users) # 셔플
    max_train_data_len = ratio*len(df) # train data 길이
    sum_of_train_data = 0
    user_ids =[]

    for user_id, count in users: # for문으로 전체의 ratio 퍼센트만 user_ids에 추가
        sum_of_train_data += count
        if max_train_data_len < sum_of_train_data:
            break
        user_ids.append(user_id)

    ## train, test split
    train = df[df['userID'].isin(user_ids)] # train
    test = df[df['userID'].isin(user_ids) == False] # test

    #test데이터셋은, train에서 각 유저의 마지막 interaction만 추출
    test = test[test['userID'] != test['userID'].shift(-1)]
    return train, test

# %%
train, valid = custom_train_test_split(train_df, ratio=0.7, seed=13) # 훈련데이터 split
test = df[df.kind=='test'] # 테스트 데이터
train2 = test[test.answerCode!=-1] # 테스트데이터 마지막 제출 2번쨰꺼까지 훈련데이터로 사용
train = pd.concat([train_df,train2]) # 훈련데이터 병합
#     train.shape, valid.shape, test.shape

x_train = train.drop('answerCode',axis=1)
y_train = train[['answerCode']]

x_valid = valid.drop('answerCode',axis=1)
y_valid = valid[['answerCode']]
x_train.shape, y_train.shape, x_valid.shape, y_valid.shape
# Out:
# ((2525956, 25), (2525956, 1), (1974, 25), (1974, 1))

# %%
df[:2]
# Out:
#    userID assessmentItemID      testId  answerCode            Timestamp  \
# 0       0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1       0       A060001002  A060000001           1  2020-03-24 00:17:14
#
#    KnowledgeTag  user_correct_answer  user_total_answer  user_acc  month  ...  \
# 0          7224                  NaN                  0       NaN      3  ...
# 1          7225                  1.0                  1       1.0      3  ...
#
#    test_mean  test_std  test_sum  tag_mean   tag_std  tag_sum   kind  \
# 0   0.947683  0.222749      1268  0.955022  0.207410      637  train
# 1   0.947683  0.222749      1268  0.913187  0.281603     3040  train
#
#    solvesec  solvesec_3600  time_category
# 0       0.0            0.0              0
# 1       3.0            3.0              1
#
# [2 rows x 26 columns]

# %% [markdown]
# ### 시드별 Validation set align

# %%
for seed in range(100):
    print(f"seed: {seed}")
    train, valid = custom_train_test_split(train_df, ratio=0.7, seed=seed) # 훈련데이터 split
    test = df[df.kind=='test'] # 테스트 데이터
    train2 = test[test.answerCode!=-1] # 테스트데이터 마지막 제출 2번쨰꺼까지 훈련데이터로 사용
    train = pd.concat([train_df,train2]) # 훈련데이터 병합
#     train.shape, valid.shape, test.shape

    x_train = train.drop('answerCode',axis=1)
    y_train = train[['answerCode']]

    x_valid = valid.drop('answerCode',axis=1)
    y_valid = valid[['answerCode']]
    # 사용할 Feature 설정
    FEATS = ['KnowledgeTag',
             'user_correct_answer',
             'user_total_answer',
             'big_category',
             'mid_category',
             'problem_num',
             'month','day','dayname','hour',
             'user_acc',
             'test_mean',
             'test_sum',
             'test_std',
             'tag_std',
             'tag_mean',
             'tag_sum',
             'solvesec'
            ]
    preds = model2.predict(x_valid[FEATS])
    acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
    auc = roc_auc_score(y_valid, preds)

    print(f'시간 초로만 추가 VALID AUC : {auc} ACC : {acc}\n')
#     x_train.shape, y_train.shape, x_valid.shape, y_valid.shape
    FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec'
        ]
    preds = model4.predict(x_valid[FEATS])
    acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
    auc = roc_auc_score(y_valid, preds)

    print(f'3600 VALID AUC : {auc} ACC : {acc}\n')
    # 사용할 Feature 설정
    FEATS = ['KnowledgeTag',
             'user_correct_answer',
             'user_total_answer',
             'big_category',
             'mid_category',
             'problem_num',
             'month','day','dayname','hour',
             'user_acc',
             'test_mean',
             'test_sum',
             'test_std',
             'tag_std',
             'tag_mean',
             'tag_sum',
             'solvesec',
             'time_category'
            ]
    preds = model5.predict(x_valid[FEATS])
    acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
    auc = roc_auc_score(y_valid, preds)

    print(f'category VALID AUC : {auc} ACC : {acc}\n')
# Out:
# seed: 0
# 시간 초로만 추가 VALID AUC : 0.8279017998383869 ACC : 0.7428861788617886
#
# 3600 VALID AUC : 0.8309100018567869 ACC : 0.7479674796747967
#
# category VALID AUC : 0.8295978033901399 ACC : 0.7469512195121951
#
# seed: 1
# 시간 초로만 추가 VALID AUC : 0.8344024124432114 ACC : 0.7573200992555831
#
# 3600 VALID AUC : 0.8343223797187196 ACC : 0.7578163771712159
#
# category VALID AUC : 0.8339913801791548 ACC : 0.75136476426799
#
# seed: 2
# 시간 초로만 추가 VALID AUC : 0.8213292695968346 ACC : 0.7404276479363501
#
# 3600 VALID AUC : 0.8197994272745637 ACC : 0.739433117851815
#
# category VALID AUC : 0.8202113459839906 ACC : 0.739433117851815
#
# seed: 3
# 시간 초로만 추가 VALID AUC : 0.8380398111330039 ACC : 0.759581881533101
#
# 3600 VALID AUC : 0.8372251140774101 ACC : 0.7590841214534594
#
# category VALID AUC : 0.835474803858215 ACC : 0.7605774016923843
#
# seed: 4
# 시간 초로만 추가 VALID AUC : 0.833747175208205 ACC : 0.7529761904761905
#
# 3600 VALID AUC : 0.8349274640876121 ACC : 0.75
#
# category VALID AUC : 0.8316029014364955 ACC : 0.7509920634920635
#
# seed: 5
# 시간 초로만 추가 VALID AUC : 0.8197048121764976 ACC : 0.7324228629236217
#
# 3600 VALID AUC : 0.8196156408548148 ACC : 0.7293879615579161
#
# category VALID AUC : 0.8182555219597192 ACC : 0.7319170460293374
#
# seed: 6
# 시간 초로만 추가 VALID AUC : 0.8374868410397602 ACC : 0.7520080321285141
#
# 3600 VALID AUC : 0.8353439549761115 ACC : 0.751004016064257
#
# category VALID AUC : 0.8353662239857478 ACC : 0.7550200803212851
#
# seed: 7
# 시간 초로만 추가 VALID AUC : 0.8257373162636321 ACC : 0.7385955920041004
#
# 3600 VALID AUC : 0.8244381223328592 ACC : 0.7355202460276781
#
# category VALID AUC : 0.824318002212739 ACC : 0.7380830343413634
#
# seed: 8
# 시간 초로만 추가 VALID AUC : 0.823228746559119 ACC : 0.7405
#
# 3600 VALID AUC : 0.8222865053453684 ACC : 0.7445
#
# category VALID AUC : 0.820619078484092 ACC : 0.741
#
# seed: 9
# 시간 초로만 추가 VALID AUC : 0.8309789932450874 ACC : 0.7458762886597938
#
# 3600 VALID AUC : 0.8310898693367904 ACC : 0.7443298969072165
#
# category VALID AUC : 0.8285461159252183 ACC : 0.7494845360824742
#
# seed: 10
# 시간 초로만 추가 VALID AUC : 0.8309499924471591 ACC : 0.7382121807465619
#
# 3600 VALID AUC : 0.8323501729406889 ACC : 0.7450884086444007
#
# category VALID AUC : 0.829872260158571 ACC : 0.7470530451866405
#
# seed: 11
# 시간 초로만 추가 VALID AUC : 0.8314255278228695 ACC : 0.744765702891326
#
# 3600 VALID AUC : 0.8304071014809036 ACC : 0.7467597208374875
#
# category VALID AUC : 0.8274614378147082 ACC : 0.7497507477567298
#
# seed: 12
# 시간 초로만 추가 VALID AUC : 0.816925863383811 ACC : 0.7272279665189562
#
# 3600 VALID AUC : 0.8151107730378349 ACC : 0.725258493353028
#
# category VALID AUC : 0.8159619006116446 ACC : 0.7296898079763663
#
# seed: 13
# 시간 초로만 추가 VALID AUC : 0.8187398163235076 ACC : 0.7406281661600811
#
# 3600 VALID AUC : 0.8199340838394311 ACC : 0.7396149949341438
#
# category VALID AUC : 0.8215223259105646 ACC : 0.7406281661600811
#
# seed: 14
# 시간 초로만 추가 VALID AUC : 0.828487907022898 ACC : 0.731290808638875
#
# 3600 VALID AUC : 0.830172803104097 ACC : 0.7363134103465595
#
# category VALID AUC : 0.8280930095038669 ACC : 0.7338021094927172
#
# seed: 15
# 시간 초로만 추가 VALID AUC : 0.8210787183389924 ACC : 0.7422784810126583
#
# 3600 VALID AUC : 0.8225186253304495 ACC : 0.7387341772151899
#
# category VALID AUC : 0.8202447636477919 ACC : 0.7412658227848101
#
# seed: 16
# 시간 초로만 추가 VALID AUC : 0.8279513068563329 ACC : 0.7497456765005086
#
# 3600 VALID AUC : 0.8270207986206096 ACC : 0.7512716174974567
#
# category VALID AUC : 0.827889134813857 ACC : 0.7497456765005086
#
# seed: 17
# 시간 초로만 추가 VALID AUC : 0.8264691295173391 ACC : 0.7389558232931727
#
# 3600 VALID AUC : 0.8286913719417652 ACC : 0.748995983935743
#
# category VALID AUC : 0.8264640789663744 ACC : 0.7429718875502008
#
# seed: 18
# 시간 초로만 추가 VALID AUC : 0.8276786768820297 ACC : 0.7425061425061426
#
# 3600 VALID AUC : 0.8267502715512987 ACC : 0.7425061425061426
#
# category VALID AUC : 0.8282672800531292 ACC : 0.7434889434889435
#
# seed: 19
# 시간 초로만 추가 VALID AUC : 0.8297604732887102 ACC : 0.7386811023622047
#
# 3600 VALID AUC : 0.8283552033322755 ACC : 0.7431102362204725
#
# category VALID AUC : 0.8285444489410494 ACC : 0.7436023622047244
#
# seed: 20
# 시간 초로만 추가 VALID AUC : 0.818023741168326 ACC : 0.7317196167423097
#
# 3600 VALID AUC : 0.816450837863702 ACC : 0.7317196167423097
#
# category VALID AUC : 0.8172785209618634 ACC : 0.7418053454362078
#
# seed: 21
# 시간 초로만 추가 VALID AUC : 0.8239397844423617 ACC : 0.7409965466206216
#
# 3600 VALID AUC : 0.8249765698219306 ACC : 0.7444499259990133
#
# category VALID AUC : 0.8243917916276163 ACC : 0.7459299457326097
#
# seed: 22
# 시간 초로만 추가 VALID AUC : 0.8199450531519992 ACC : 0.7344775365976779
#
# 3600 VALID AUC : 0.8216613773016898 ACC : 0.7390206966178697
#
# category VALID AUC : 0.8203815277426514 ACC : 0.740535083291267
#
# seed: 23
# 시간 초로만 추가 VALID AUC : 0.8368655496356787 ACC : 0.7441624365482233
#
# 3600 VALID AUC : 0.8358987286096035 ACC : 0.749238578680203
#
# category VALID AUC : 0.8352213314743813 ACC : 0.7538071065989848
#
# seed: 24
# 시간 초로만 추가 VALID AUC : 0.8326889762116026 ACC : 0.7431506849315068
#
# 3600 VALID AUC : 0.8348150666251821 ACC : 0.74706457925636
#
# category VALID AUC : 0.8356601251454845 ACC : 0.7524461839530333
#
# seed: 25
# 시간 초로만 추가 VALID AUC : 0.8244945819767989 ACC : 0.7461851475076297
#
# 3600 VALID AUC : 0.8253087615458639 ACC : 0.7451678535096643
#
# category VALID AUC : 0.8214906115565849 ACC : 0.7487283825025433
#
# seed: 26
# 시간 초로만 추가 VALID AUC : 0.8311411774633626 ACC : 0.7486708554857419
#
# 3600 VALID AUC : 0.8292574986170103 ACC : 0.7525374577090382
#
# category VALID AUC : 0.8295584746795683 ACC : 0.7515708071532141
#
# seed: 27
# 시간 초로만 추가 VALID AUC : 0.8312596633938332 ACC : 0.7488855869242199
#
# 3600 VALID AUC : 0.8319116039510355 ACC : 0.7523526498266468
#
# category VALID AUC : 0.8324040061845721 ACC : 0.7508667657256067
#
# seed: 28
# 시간 초로만 추가 VALID AUC : 0.8251647890699905 ACC : 0.7413879181228158
#
# 3600 VALID AUC : 0.8277804410354745 ACC : 0.7423864203694458
#
# category VALID AUC : 0.8251348274209013 ACC : 0.7503744383424863
#
# seed: 29
# 시간 초로만 추가 VALID AUC : 0.8216828026749177 ACC : 0.7359242650722472
#
# 3600 VALID AUC : 0.8197045613334664 ACC : 0.7384155455904334
#
# category VALID AUC : 0.819688591675816 ACC : 0.7389138016940707
#
# seed: 30
# 시간 초로만 추가 VALID AUC : 0.81727768542013 ACC : 0.7249498997995992
#
# 3600 VALID AUC : 0.8175804039532426 ACC : 0.7274549098196392
#
# category VALID AUC : 0.8166521341656584 ACC : 0.7299599198396793
#
# seed: 31
# 시간 초로만 추가 VALID AUC : 0.8297667344858535 ACC : 0.7473578258681429
#
# 3600 VALID AUC : 0.8323789914840218 ACC : 0.7503774534474081
#
# category VALID AUC : 0.829205297206418 ACC : 0.7569199798691495
#
# seed: 32
# 시간 초로만 추가 VALID AUC : 0.835570356878074 ACC : 0.7526041666666666
#
# 3600 VALID AUC : 0.835500885220882 ACC : 0.7546875
#
# category VALID AUC : 0.8329065530226142 ACC : 0.7546875
#
# seed: 33
# 시간 초로만 추가 VALID AUC : 0.8314642153383005 ACC : 0.7528649725959143
#
# 3600 VALID AUC : 0.83318519579011 ACC : 0.7543597409068261
#
# category VALID AUC : 0.831324031488673 ACC : 0.7543597409068261
#
# seed: 34
# 시간 초로만 추가 VALID AUC : 0.8311653228341507 ACC : 0.7465346534653465
#
# 3600 VALID AUC : 0.8327321451024772 ACC : 0.747029702970297
#
# category VALID AUC : 0.8325346960266566 ACC : 0.7514851485148515
#
# seed: 35
# 시간 초로만 추가 VALID AUC : 0.8238856686410788 ACC : 0.7370313302516692
#
# 3600 VALID AUC : 0.8267743823710275 ACC : 0.7498715973292245
#
# category VALID AUC : 0.8245618854615497 ACC : 0.7467899332306112
#
# seed: 36
# 시간 초로만 추가 VALID AUC : 0.8181445650043652 ACC : 0.736214605067064
#
# 3600 VALID AUC : 0.8189829414641001 ACC : 0.7421758569299552
#
# category VALID AUC : 0.8174675289967395 ACC : 0.7391952309985097
#
# seed: 37
# 시간 초로만 추가 VALID AUC : 0.8266403621923768 ACC : 0.7402010050251256
#
# 3600 VALID AUC : 0.8253716771631636 ACC : 0.7437185929648241
#
# category VALID AUC : 0.8264501606090497 ACC : 0.7396984924623116
#
# seed: 38
# 시간 초로만 추가 VALID AUC : 0.8288681650478706 ACC : 0.7444933920704846
#
# 3600 VALID AUC : 0.8321917676328092 ACC : 0.7440039158100832
#
# category VALID AUC : 0.8316246755347418 ACC : 0.7454723445912873
#
# seed: 39
# 시간 초로만 추가 VALID AUC : 0.8256697432427414 ACC : 0.7389984825493171
#
# 3600 VALID AUC : 0.8281669685479578 ACC : 0.7369752149721801
#
# category VALID AUC : 0.8269828237109532 ACC : 0.7415275670207385
#
# seed: 40
# 시간 초로만 추가 VALID AUC : 0.8351401171427032 ACC : 0.7551420176297747
#
# 3600 VALID AUC : 0.8359886705611613 ACC : 0.7590597453476984
#
# category VALID AUC : 0.8337604962786795 ACC : 0.7590597453476984
#
# seed: 41
# 시간 초로만 추가 VALID AUC : 0.8159614779525173 ACC : 0.7378497790868925
#
# 3600 VALID AUC : 0.8174671502834718 ACC : 0.7309769268532155
#
# category VALID AUC : 0.8167123837688522 ACC : 0.7349042709867453
#
# seed: 42
# 시간 초로만 추가 VALID AUC : 0.8229596501689525 ACC : 0.7448928749377179
#
# 3600 VALID AUC : 0.8232269926455973 ACC : 0.752366716492277
#
# category VALID AUC : 0.8227767839395747 ACC : 0.7518684603886397
#
# seed: 43
# 시간 초로만 추가 VALID AUC : 0.8300425251932 ACC : 0.7410938283993979
#
# 3600 VALID AUC : 0.8288154099836316 ACC : 0.7375815353738083
#
# category VALID AUC : 0.8277820498071531 ACC : 0.7441043652784747
#
# seed: 44
# 시간 초로만 추가 VALID AUC : 0.8386049044039119 ACC : 0.7485976542580316
#
# 3600 VALID AUC : 0.8389849852365296 ACC : 0.7485976542580316
#
# category VALID AUC : 0.8395001361171025 ACC : 0.7557368689444162
#
# seed: 45
# 시간 초로만 추가 VALID AUC : 0.827697877209596 ACC : 0.7366071428571429
#
# 3600 VALID AUC : 0.8278369633838383 ACC : 0.7371031746031746
#
# category VALID AUC : 0.8263356218434342 ACC : 0.7371031746031746
#
# seed: 46
# 시간 초로만 추가 VALID AUC : 0.8134282086237137 ACC : 0.7289094650205762
#
# 3600 VALID AUC : 0.8139548216947599 ACC : 0.7304526748971193
#
# category VALID AUC : 0.812867620515826 ACC : 0.7330246913580247
#
# seed: 47
# 시간 초로만 추가 VALID AUC : 0.8246942176240983 ACC : 0.7422330097087378
#
# 3600 VALID AUC : 0.8247499518229807 ACC : 0.7407766990291262
#
# category VALID AUC : 0.8234557848319851 ACC : 0.7412621359223301
#
# seed: 48
# 시간 초로만 추가 VALID AUC : 0.8271860700041453 ACC : 0.7418546365914787
#
# 3600 VALID AUC : 0.8301995001428739 ACC : 0.7388471177944862
#
# category VALID AUC : 0.828341134377855 ACC : 0.7478696741854637
#
# seed: 49
# 시간 초로만 추가 VALID AUC : 0.8298739123283495 ACC : 0.7435
#
# 3600 VALID AUC : 0.8315337524220627 ACC : 0.747
#
# category VALID AUC : 0.8297435321397194 ACC : 0.749
#
# seed: 50
# 시간 초로만 추가 VALID AUC : 0.8183030382203643 ACC : 0.7327544621321755
#
# 3600 VALID AUC : 0.8194181098835474 ACC : 0.7370959961408586
#
# category VALID AUC : 0.818123880262765 ACC : 0.7370959961408586
#
# seed: 51
# 시간 초로만 추가 VALID AUC : 0.8340237324251742 ACC : 0.7514066496163683
#
# 3600 VALID AUC : 0.8366862518132134 ACC : 0.7585677749360614
#
# category VALID AUC : 0.8367459073183698 ACC : 0.7575447570332481
#
# seed: 52
# 시간 초로만 추가 VALID AUC : 0.8374619953689721 ACC : 0.751503006012024
#
# 3600 VALID AUC : 0.837660324171952 ACC : 0.748997995991984
#
# category VALID AUC : 0.8378908688211015 ACC : 0.75
#
# seed: 53
# 시간 초로만 추가 VALID AUC : 0.825786446128061 ACC : 0.7366375121477162
#
# 3600 VALID AUC : 0.826669965645121 ACC : 0.7410106899902819
#
# category VALID AUC : 0.8259694067147483 ACC : 0.7439261418853256
#
# seed: 54
# 시간 초로만 추가 VALID AUC : 0.8131891986569127 ACC : 0.7316955684007708
#
# 3600 VALID AUC : 0.8130895105781163 ACC : 0.7321772639691715
#
# category VALID AUC : 0.8123562907836042 ACC : 0.7312138728323699
#
# seed: 55
# 시간 초로만 추가 VALID AUC : 0.8242200672085208 ACC : 0.7338908017707821
#
# 3600 VALID AUC : 0.824505916597869 ACC : 0.7397934087555337
#
# category VALID AUC : 0.8255717956767945 ACC : 0.7417609444171176
#
# seed: 56
# 시간 초로만 추가 VALID AUC : 0.8329691222644726 ACC : 0.7548387096774194
#
# 3600 VALID AUC : 0.8322472743337699 ACC : 0.7553349875930521
#
# category VALID AUC : 0.8304120844443744 ACC : 0.7553349875930521
#
# seed: 57
# 시간 초로만 추가 VALID AUC : 0.8269199831699832 ACC : 0.7398580121703854
#
# 3600 VALID AUC : 0.8280378592878592 ACC : 0.742393509127789
#
# category VALID AUC : 0.8275872025872026 ACC : 0.744421906693712
#
# seed: 58
# 시간 초로만 추가 VALID AUC : 0.8351715913215458 ACC : 0.7537277537277537
#
# 3600 VALID AUC : 0.8374400930363479 ACC : 0.7537277537277537
#
# category VALID AUC : 0.8368058384752706 ACC : 0.7585377585377585
#
# seed: 59
# 시간 초로만 추가 VALID AUC : 0.8319320196647324 ACC : 0.7462387161484454
#
# 3600 VALID AUC : 0.8332990812379111 ACC : 0.7492477432296891
#
# category VALID AUC : 0.8302828820116054 ACC : 0.7472417251755266
#
# seed: 60
# 시간 초로만 추가 VALID AUC : 0.8268796061187837 ACC : 0.7539292730844793
#
# 3600 VALID AUC : 0.8269096039511984 ACC : 0.7554027504911591
#
# category VALID AUC : 0.8254019709543567 ACC : 0.7534381139489195
#
# seed: 61
# 시간 초로만 추가 VALID AUC : 0.8323071151363828 ACC : 0.744987146529563
#
# 3600 VALID AUC : 0.8333986862994042 ACC : 0.748586118251928
#
# category VALID AUC : 0.8291182436514009 ACC : 0.7480719794344473
#
# seed: 62
# 시간 초로만 추가 VALID AUC : 0.8189828102023224 ACC : 0.7398087569199798
#
# 3600 VALID AUC : 0.820210942649967 ACC : 0.7398087569199798
#
# category VALID AUC : 0.8175721312306679 ACC : 0.7443381982888777
#
# seed: 63
# 시간 초로만 추가 VALID AUC : 0.8190931612605865 ACC : 0.7326633165829146
#
# 3600 VALID AUC : 0.8185331970821218 ACC : 0.7321608040201005
#
# category VALID AUC : 0.8187848777327313 ACC : 0.735678391959799
#
# seed: 64
# 시간 초로만 추가 VALID AUC : 0.8331993335298027 ACC : 0.744390243902439
#
# 3600 VALID AUC : 0.8321425948656616 ACC : 0.7473170731707317
#
# category VALID AUC : 0.832606110200294 ACC : 0.748780487804878
#
# seed: 65
# 시간 초로만 추가 VALID AUC : 0.823146980245712 ACC : 0.730979612133267
#
# 3600 VALID AUC : 0.824844319524864 ACC : 0.7329686723023372
#
# category VALID AUC : 0.8235819917169049 ACC : 0.7319741422178021
#
# seed: 66
# 시간 초로만 추가 VALID AUC : 0.8305876172290816 ACC : 0.7404397705544933
#
# 3600 VALID AUC : 0.8307106899696634 ACC : 0.7461759082217974
#
# category VALID AUC : 0.8296103829307294 ACC : 0.7476099426386233
#
# seed: 67
# 시간 초로만 추가 VALID AUC : 0.8085889260046563 ACC : 0.7270446562970396
#
# 3600 VALID AUC : 0.8080514222087256 ACC : 0.728549924736578
#
# category VALID AUC : 0.8062607551371597 ACC : 0.7235323632714501
#
# seed: 68
# 시간 초로만 추가 VALID AUC : 0.8223910236105357 ACC : 0.7412060301507538
#
# 3600 VALID AUC : 0.8229524540500149 ACC : 0.7422110552763819
#
# category VALID AUC : 0.8217768004353371 ACC : 0.7396984924623116
#
# seed: 69
# 시간 초로만 추가 VALID AUC : 0.8329573995893869 ACC : 0.74658203125
#
# 3600 VALID AUC : 0.8316982365029277 ACC : 0.7470703125
#
# category VALID AUC : 0.8318348528317318 ACC : 0.74560546875
#
# seed: 70
# 시간 초로만 추가 VALID AUC : 0.831680420270996 ACC : 0.7403508771929824
#
# 3600 VALID AUC : 0.8323139643163858 ACC : 0.7483709273182957
#
# category VALID AUC : 0.8314501320386241 ACC : 0.7478696741854637
#
# seed: 71
# 시간 초로만 추가 VALID AUC : 0.8394154767665812 ACC : 0.7543082225504677
#
# 3600 VALID AUC : 0.8410946497738754 ACC : 0.7538158542589857
#
# category VALID AUC : 0.8402171652683276 ACC : 0.7528311176760216
#
# seed: 72
# 시간 초로만 추가 VALID AUC : 0.8279448418258241 ACC : 0.7400990099009901
#
# 3600 VALID AUC : 0.831666297962294 ACC : 0.746039603960396
#
# category VALID AUC : 0.8293567337708624 ACC : 0.7445544554455445
#
# seed: 73
# 시간 초로만 추가 VALID AUC : 0.8201541074689697 ACC : 0.7336609336609337
#
# 3600 VALID AUC : 0.8210014470548178 ACC : 0.7346437346437347
#
# category VALID AUC : 0.8196375785433497 ACC : 0.7351351351351352
#
# seed: 74
# 시간 초로만 추가 VALID AUC : 0.8287104459644425 ACC : 0.7451737451737451
#
# 3600 VALID AUC : 0.8325008129535884 ACC : 0.7495173745173745
#
# category VALID AUC : 0.8313612803017386 ACC : 0.749034749034749
#
# seed: 75
# 시간 초로만 추가 VALID AUC : 0.8191274019825148 ACC : 0.738562091503268
#
# 3600 VALID AUC : 0.8194097797857978 ACC : 0.7420814479638009
#
# category VALID AUC : 0.8176679439454759 ACC : 0.7410759175465058
#
# seed: 76
# 시간 초로만 추가 VALID AUC : 0.8260829424290284 ACC : 0.7403560830860534
#
# 3600 VALID AUC : 0.8270042194092828 ACC : 0.7453016815034619
#
# category VALID AUC : 0.8272477979712263 ACC : 0.7457962413452027
#
# seed: 77
# 시간 초로만 추가 VALID AUC : 0.8246652872444011 ACC : 0.7389336016096579
#
# 3600 VALID AUC : 0.8262597370983447 ACC : 0.7364185110663984
#
# category VALID AUC : 0.8254117981174942 ACC : 0.7510060362173038
#
# seed: 78
# 시간 초로만 추가 VALID AUC : 0.8362746177024369 ACC : 0.7432969215491559
#
# 3600 VALID AUC : 0.8367376481424746 ACC : 0.7492552135054618
#
# category VALID AUC : 0.8354328343114479 ACC : 0.7482621648460774
#
# seed: 79
# 시간 초로만 추가 VALID AUC : 0.8125951523172317 ACC : 0.7227722772277227
#
# 3600 VALID AUC : 0.8165370193368134 ACC : 0.7257425742574257
#
# category VALID AUC : 0.8155939514251404 ACC : 0.7356435643564356
#
# seed: 80
# 시간 초로만 추가 VALID AUC : 0.8325044327730677 ACC : 0.7476403378042722
#
# 3600 VALID AUC : 0.8322197864757428 ACC : 0.7476403378042722
#
# category VALID AUC : 0.8316633424986806 ACC : 0.7521112767014406
#
# seed: 81
# 시간 초로만 추가 VALID AUC : 0.8172385457169198 ACC : 0.7392392392392393
#
# 3600 VALID AUC : 0.8162624764500742 ACC : 0.7367367367367368
#
# category VALID AUC : 0.8149086062452399 ACC : 0.7412412412412412
#
# seed: 82
# 시간 초로만 추가 VALID AUC : 0.8335558964618792 ACC : 0.745069033530572
#
# 3600 VALID AUC : 0.8330883677892225 ACC : 0.75
#
# category VALID AUC : 0.8325672681228237 ACC : 0.7519723865877712
#
# seed: 83
# 시간 초로만 추가 VALID AUC : 0.8258995906054729 ACC : 0.7454282964388835
#
# 3600 VALID AUC : 0.8278026064537221 ACC : 0.7492781520692974
#
# category VALID AUC : 0.8272648581979211 ACC : 0.7478344562078922
#
# seed: 84
# 시간 초로만 추가 VALID AUC : 0.8217419125488803 ACC : 0.7340050377833753
#
# 3600 VALID AUC : 0.8204611243715403 ACC : 0.7365239294710327
#
# category VALID AUC : 0.8180244781880047 ACC : 0.7360201511335013
#
# seed: 85
# 시간 초로만 추가 VALID AUC : 0.8259744056250697 ACC : 0.7411764705882353
#
# 3600 VALID AUC : 0.8262176945060947 ACC : 0.7436274509803922
#
# category VALID AUC : 0.8247993107135576 ACC : 0.7465686274509804
#
# seed: 86
# 시간 초로만 추가 VALID AUC : 0.8227189934998808 ACC : 0.7439684884293452
#
# 3600 VALID AUC : 0.8234512510450429 ACC : 0.7474150664697193
#
# category VALID AUC : 0.8226821381532368 ACC : 0.7474150664697193
#
# seed: 87
# 시간 초로만 추가 VALID AUC : 0.8380504577527164 ACC : 0.7484848484848485
#
# 3600 VALID AUC : 0.8392331093292267 ACC : 0.7555555555555555
#
# category VALID AUC : 0.838598266058719 ACC : 0.752020202020202
#
# seed: 88
# 시간 초로만 추가 VALID AUC : 0.8126878743220645 ACC : 0.7385458167330677
#
# 3600 VALID AUC : 0.8140216641608486 ACC : 0.7380478087649402
#
# category VALID AUC : 0.8143729748773142 ACC : 0.7440239043824701
#
# seed: 89
# 시간 초로만 추가 VALID AUC : 0.8301677597014384 ACC : 0.7431332655137335
#
# 3600 VALID AUC : 0.8330943667731232 ACC : 0.7477110885045778
#
# category VALID AUC : 0.8320943305399264 ACC : 0.7446592065106816
#
# seed: 90
# 시간 초로만 추가 VALID AUC : 0.8244882625294452 ACC : 0.7403120281831908
#
# 3600 VALID AUC : 0.8271728535456097 ACC : 0.7423251132360342
#
# category VALID AUC : 0.825870156770368 ACC : 0.7508807247106191
#
# seed: 91
# 시간 초로만 추가 VALID AUC : 0.8244254181363067 ACC : 0.7376333656644035
#
# 3600 VALID AUC : 0.8237920506693973 ACC : 0.7371483996120272
#
# category VALID AUC : 0.8237740357264765 ACC : 0.7327837051406402
#
# seed: 92
# 시간 초로만 추가 VALID AUC : 0.831731951080861 ACC : 0.7454723445912873
#
# 3600 VALID AUC : 0.8296453208782091 ACC : 0.7410670582476749
#
# category VALID AUC : 0.8278458063822268 ACC : 0.7484092021536956
#
# seed: 93
# 시간 초로만 추가 VALID AUC : 0.819100535491404 ACC : 0.7364899639732373
#
# 3600 VALID AUC : 0.8198294988588756 ACC : 0.7390633041688112
#
# category VALID AUC : 0.8179710660877342 ACC : 0.7354606278950078
#
# seed: 94
# 시간 초로만 추가 VALID AUC : 0.8245271753379095 ACC : 0.7410845139228138
#
# 3600 VALID AUC : 0.8237368218604499 ACC : 0.7381533952125061
#
# category VALID AUC : 0.8217255349238638 ACC : 0.7425500732779677
#
# seed: 95
# 시간 초로만 추가 VALID AUC : 0.8186481411795741 ACC : 0.7351058591826687
#
# 3600 VALID AUC : 0.8193493449612254 ACC : 0.7351058591826687
#
# category VALID AUC : 0.8174280659965628 ACC : 0.7395371738060069
#
# seed: 96
# 시간 초로만 추가 VALID AUC : 0.831714939207897 ACC : 0.7490196078431373
#
# 3600 VALID AUC : 0.8321916456000963 ACC : 0.7524509803921569
#
# category VALID AUC : 0.8313393523534369 ACC : 0.7553921568627451
#
# seed: 97
# 시간 초로만 추가 VALID AUC : 0.8301475984229308 ACC : 0.7421800947867299
#
# 3600 VALID AUC : 0.8286403174283412 ACC : 0.7431279620853081
#
# category VALID AUC : 0.8288705465062738 ACC : 0.7516587677725118
#
# seed: 98
# 시간 초로만 추가 VALID AUC : 0.8315000400152947 ACC : 0.7333664349553128
#
# 3600 VALID AUC : 0.8321422607949904 ACC : 0.7388282025819265
#
# category VALID AUC : 0.8303983843701246 ACC : 0.7423038728897716
#
# seed: 99
# 시간 초로만 추가 VALID AUC : 0.8168773631238826 ACC : 0.7328282828282828
#
# 3600 VALID AUC : 0.8193340419514157 ACC : 0.7368686868686869
#
# category VALID AUC : 0.8168528575994185 ACC : 0.7348484848484849

# %% [markdown]
# #### seed 13이 적절
# seed: 13
# 시간 초로만 추가 VALID AUC : 0.8187398163235076 ACC : 0.7406281661600811
#
# 3600 VALID AUC : 0.8199340838394311 ACC : 0.7396149949341438
#
# category VALID AUC : 0.8215223259105646 ACC : 0.7406281661600811

# %%
# 사용할 Feature 설정
FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec'
        ]

params = {
#     "max_depth": 8,  # 8,
#     "min_data_in_leaf": 1000,
    # "feature_fraction": 0.6,  # 0.8,
#     "bagging_fraction": 0.75,
    # "max_cat_group": 64,
    "objective": "binary",
#     "boosting": "gbdt",  # dart
#     "learning_rate": 0.01,  # 0.01,
    # "bagging_freq": 5,
    "seed": 42,
    # "max_bin": 50,
#     "num_leaves": 80,  # 40,
#     "metric": "auc",
}

model_auc = lgb.LGBMClassifier(
    **params,
    n_estimators=3200,
    silent=-1,
)

# %% [markdown]
# ## 문제푼 시간 초로만 추가한 것

# %%
lgb_x_train = lgb.Dataset(x_train[FEATS], y_train)
lgb_x_valid = lgb.Dataset(x_valid[FEATS], y_valid)

model2 = lgb.train(
    params, 
    lgb_x_train,
    valid_sets=[lgb_x_valid],
    verbose_eval=100,
    num_boost_round=3200,
#     early_stopping_rounds=200,
)

preds = model2.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')

post_slack("done")
# Out:
# [LightGBM] [Info] Number of positive: 1653588, number of negative: 872368
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.238892 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3095
# [LightGBM] [Info] Number of data points in the train set: 2525956, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654638 -> initscore=0.639491
# [LightGBM] [Info] Start training from score 0.639491
# [100]	valid_0's binary_logloss: 0.582419
# [200]	valid_0's binary_logloss: 0.575168
# [300]	valid_0's binary_logloss: 0.568893
# [400]	valid_0's binary_logloss: 0.563229
# [500]	valid_0's binary_logloss: 0.559829
# [600]	valid_0's binary_logloss: 0.556637
# [700]	valid_0's binary_logloss: 0.553144
# [800]	valid_0's binary_logloss: 0.550667
# [900]	valid_0's binary_logloss: 0.548314
# [1000]	valid_0's binary_logloss: 0.546135
# [1100]	valid_0's binary_logloss: 0.542614
# [1200]	valid_0's binary_logloss: 0.540631
# [1300]	valid_0's binary_logloss: 0.539541
# [1400]	valid_0's binary_logloss: 0.537865
# [1500]	valid_0's binary_logloss: 0.536437
# [1600]	valid_0's binary_logloss: 0.534883
# [1700]	valid_0's binary_logloss: 0.532909
# [1800]	valid_0's binary_logloss: 0.531226
# [1900]	valid_0's binary_logloss: 0.530395
# [2000]	valid_0's binary_logloss: 0.528694
# [2100]	valid_0's binary_logloss: 0.527385
# [2200]	valid_0's binary_logloss: 0.5261
# [2300]	valid_0's binary_logloss: 0.52483
# [2400]	valid_0's binary_logloss: 0.524006
# [2500]	valid_0's binary_logloss: 0.522985
# [2600]	valid_0's binary_logloss: 0.521911
# [2700]	valid_0's binary_logloss: 0.519999
# [2800]	valid_0's binary_logloss: 0.519164
# [2900]	valid_0's binary_logloss: 0.518294
# [3000]	valid_0's binary_logloss: 0.517839
# [3100]	valid_0's binary_logloss: 0.516759
# [3200]	valid_0's binary_logloss: 0.515955
# VALID AUC : 0.8229596501689525 ACC : 0.7448928749377179

# %% [markdown]
# ### validation

# %%
# 사용할 Feature 설정
FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec'
        ]
preds = model2.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# VALID AUC : 0.8187398163235076 ACC : 0.7406281661600811

# %% [markdown]
# ## 문제푼 시간 4800초 이상 모두 4800초로 변환

# %%
lgb_x_train = lgb.Dataset(x_train[FEATS], y_train)
lgb_x_valid = lgb.Dataset(x_valid[FEATS], y_valid)

model3 = lgb.train(
    params, 
    lgb_x_train,
    valid_sets=[lgb_x_valid],
    verbose_eval=100,
    num_boost_round=3200,
#     early_stopping_rounds=200,
)

preds = model3.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# [LightGBM] [Info] Number of positive: 1653588, number of negative: 872368
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.067944 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3095
# [LightGBM] [Info] Number of data points in the train set: 2525956, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654638 -> initscore=0.639491
# [LightGBM] [Info] Start training from score 0.639491
# [100]	valid_0's binary_logloss: 0.56096
# [200]	valid_0's binary_logloss: 0.554025
# [300]	valid_0's binary_logloss: 0.547694
# [400]	valid_0's binary_logloss: 0.542811
# [500]	valid_0's binary_logloss: 0.536767
# [600]	valid_0's binary_logloss: 0.533314
# [700]	valid_0's binary_logloss: 0.530218
# [800]	valid_0's binary_logloss: 0.527721
# [900]	valid_0's binary_logloss: 0.525034
# [1000]	valid_0's binary_logloss: 0.522923
# [1100]	valid_0's binary_logloss: 0.520484
# [1200]	valid_0's binary_logloss: 0.518743
# [1300]	valid_0's binary_logloss: 0.516943
# [1400]	valid_0's binary_logloss: 0.515161
# [1500]	valid_0's binary_logloss: 0.513018
# [1600]	valid_0's binary_logloss: 0.512013
# [1700]	valid_0's binary_logloss: 0.510849
# [1800]	valid_0's binary_logloss: 0.509057
# [1900]	valid_0's binary_logloss: 0.507737
# [2000]	valid_0's binary_logloss: 0.506483
# [2100]	valid_0's binary_logloss: 0.505521
# [2200]	valid_0's binary_logloss: 0.504641
# [2300]	valid_0's binary_logloss: 0.503526
# [2400]	valid_0's binary_logloss: 0.502971
# [2500]	valid_0's binary_logloss: 0.502471
# [2600]	valid_0's binary_logloss: 0.502001
# [2700]	valid_0's binary_logloss: 0.500928
# [2800]	valid_0's binary_logloss: 0.499918
# [2900]	valid_0's binary_logloss: 0.49838
# [3000]	valid_0's binary_logloss: 0.497592
# [3100]	valid_0's binary_logloss: 0.496223
# [3200]	valid_0's binary_logloss: 0.495367
# VALID AUC : 0.8421447482720068 ACC : 0.765274949083503

# %%
# 사용할 Feature 설정
FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec'
        ]
preds = model3.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# VALID AUC : 0.8302605814985996 ACC : 0.7531645569620253

# %%
post_slack("done")

# %%
lgbm_predict(test, model3, FEATS, 'LGBM_Baseline_문제푼시간_추가_4800초로수렴.csv')
# Out:
# writing prediction : output/LGBM_Baseline_문제푼시간_추가_4800초로수렴.csv

# %% [markdown]
# ## 문제푼 시간 3600초 이상 모두 3600으로 변환

# %%
lgb_x_train = lgb.Dataset(x_train[FEATS], y_train)
lgb_x_valid = lgb.Dataset(x_valid[FEATS], y_valid)

model4 = lgb.train(
    params, 
    lgb_x_train,
    valid_sets=[lgb_x_valid],
    verbose_eval=100,
    num_boost_round=3200,
#     early_stopping_rounds=200,
)

preds = model4.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')

post_slack("done")

lgbm_predict(test, model4, FEATS, 'LGBM_Baseline_문제푼시간_추가_3600초이상모두3600으로.csv')
# Out:
# [LightGBM] [Info] Number of positive: 1653588, number of negative: 872368
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052752 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3095
# [LightGBM] [Info] Number of data points in the train set: 2525956, number of used features: 18
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654638 -> initscore=0.639491
# [LightGBM] [Info] Start training from score 0.639491
# [100]	valid_0's binary_logloss: 0.57308
# [200]	valid_0's binary_logloss: 0.564389
# [300]	valid_0's binary_logloss: 0.559807
# [400]	valid_0's binary_logloss: 0.554239
# [500]	valid_0's binary_logloss: 0.550381
# [600]	valid_0's binary_logloss: 0.547333
# [700]	valid_0's binary_logloss: 0.542663
# [800]	valid_0's binary_logloss: 0.539448
# [900]	valid_0's binary_logloss: 0.537293
# [1000]	valid_0's binary_logloss: 0.533369
# [1100]	valid_0's binary_logloss: 0.530778
# [1200]	valid_0's binary_logloss: 0.528895
# [1300]	valid_0's binary_logloss: 0.526897
# [1400]	valid_0's binary_logloss: 0.525646
# [1500]	valid_0's binary_logloss: 0.523441
# [1600]	valid_0's binary_logloss: 0.521941
# [1700]	valid_0's binary_logloss: 0.520392
# [1800]	valid_0's binary_logloss: 0.518991
# [1900]	valid_0's binary_logloss: 0.518401
# [2000]	valid_0's binary_logloss: 0.516927
# [2100]	valid_0's binary_logloss: 0.515664
# [2200]	valid_0's binary_logloss: 0.514235
# [2300]	valid_0's binary_logloss: 0.512859
# [2400]	valid_0's binary_logloss: 0.511646
# [2500]	valid_0's binary_logloss: 0.510438
# [2600]	valid_0's binary_logloss: 0.509123
# [2700]	valid_0's binary_logloss: 0.508236
# [2800]	valid_0's binary_logloss: 0.506781
# [2900]	valid_0's binary_logloss: 0.505248
# [3000]	valid_0's binary_logloss: 0.503842
# [3100]	valid_0's binary_logloss: 0.503227
# [3200]	valid_0's binary_logloss: 0.502616
# VALID AUC : 0.833218683431184 ACC : 0.7585328578706062
#
# writing prediction : output/LGBM_Baseline_문제푼시간_추가_3600초이상모두3600으로.csv

# %% [markdown]
# ### validation

# %%
# 사용할 Feature 설정
FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec_3600'
        ]
preds = model4.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# VALID AUC : 0.8199340838394311 ACC : 0.7396149949341438

# %%
lgbm_predict(test, model4, FEATS, 'LGBM_Baseline_문제푼시간_추가_3600초이상모두3600으로.csv')
# Out:
# writing prediction : output/LGBM_Baseline_문제푼시간_추가_3600초이상모두3600으로.csv

# %% [markdown]
# ## 문제푼 시간 카테고리 변수도 추가

# %%
# 사용할 Feature 설정
FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec',
         'time_category'
        ]

# %%
lgb_x_train = lgb.Dataset(x_train[FEATS], y_train)
lgb_x_valid = lgb.Dataset(x_valid[FEATS], y_valid)

model5 = lgb.train(
    params, 
    lgb_x_train,
    valid_sets=[lgb_x_valid],
    verbose_eval=100,
    num_boost_round=3200,
#     early_stopping_rounds=200,
)

preds = model5.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# [LightGBM] [Info] Number of positive: 1653588, number of negative: 872368
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.052055 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3105
# [LightGBM] [Info] Number of data points in the train set: 2525956, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.654638 -> initscore=0.639491
# [LightGBM] [Info] Start training from score 0.639491
# [100]	valid_0's binary_logloss: 0.560899
# [200]	valid_0's binary_logloss: 0.552517
# [300]	valid_0's binary_logloss: 0.547221
# [400]	valid_0's binary_logloss: 0.540192
# [500]	valid_0's binary_logloss: 0.535174
# [600]	valid_0's binary_logloss: 0.531541
# [700]	valid_0's binary_logloss: 0.527031
# [800]	valid_0's binary_logloss: 0.523995
# [900]	valid_0's binary_logloss: 0.522249
# [1000]	valid_0's binary_logloss: 0.519503
# [1100]	valid_0's binary_logloss: 0.517507
# [1200]	valid_0's binary_logloss: 0.515138
# [1300]	valid_0's binary_logloss: 0.513333
# [1400]	valid_0's binary_logloss: 0.512368
# [1500]	valid_0's binary_logloss: 0.51115
# [1600]	valid_0's binary_logloss: 0.508772
# [1700]	valid_0's binary_logloss: 0.506849
# [1800]	valid_0's binary_logloss: 0.505565
# [1900]	valid_0's binary_logloss: 0.504702
# [2000]	valid_0's binary_logloss: 0.503444
# [2100]	valid_0's binary_logloss: 0.502423
# [2200]	valid_0's binary_logloss: 0.501213
# [2300]	valid_0's binary_logloss: 0.500003
# [2400]	valid_0's binary_logloss: 0.498803
# [2500]	valid_0's binary_logloss: 0.497972
# [2600]	valid_0's binary_logloss: 0.497296
# [2700]	valid_0's binary_logloss: 0.495479
# [2800]	valid_0's binary_logloss: 0.494779
# [2900]	valid_0's binary_logloss: 0.493667
# [3000]	valid_0's binary_logloss: 0.492022
# [3100]	valid_0's binary_logloss: 0.491094
# [3200]	valid_0's binary_logloss: 0.490305
# VALID AUC : 0.8475305221483802 ACC : 0.7694510739856802

# %% [markdown]
# ### validation

# %%
x_train.time_category.value_counts()
# Out:
# 4    1008577
# 5     552061
# 1     364569
# 9     362015
# 3     102175
# 2      69147
# 6      27380
# 7      16761
# 0      15711
# 8       7560
# Name: time_category, dtype: int64

# %%
# 사용할 Feature 설정
FEATS = ['KnowledgeTag',
         'user_correct_answer',
         'user_total_answer',
         'big_category',
         'mid_category',
         'problem_num',
         'month','day','dayname','hour',
         'user_acc',
         'test_mean',
         'test_sum',
         'test_std',
         'tag_std',
         'tag_mean',
         'tag_sum',
         'solvesec_3600',
         'time_category'
        ]
preds = model5.predict(x_valid[FEATS])
acc = accuracy_score(y_valid, np.where(preds >= 0.5, 1, 0))
auc = roc_auc_score(y_valid, preds)

print(f'VALID AUC : {auc} ACC : {acc}\n')
# Out:
# VALID AUC : 0.8215223259105646 ACC : 0.7406281661600811

# %%
post_slack("done")

# %%
lgbm_predict(test, model5, FEATS, 'LGBM_Baseline_문제푼시간_추가_최대3600으로_time_category추가.csv')
# Out:
# writing prediction : output/LGBM_Baseline_문제푼시간_추가_최대3600으로_time_category추가.csv
