# %%
import pandas as pd
import seaborn as sns

# %%
sub_top = pd.read_csv("/opt/ml/dkt_team/code/dkt/output/output_top.csv")
sns.distplot(sub_top['prediction'], bins=30)
# Out:
# /tmp/ipykernel_99675/3111470768.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sub_top['prediction'], bins=30)
# <AxesSubplot: xlabel='prediction', ylabel='Density'>

# %%
sub_lqt = pd.read_csv("/opt/ml/dkt_team/code/dkt/output/submission_each_param_lgcnlqt.csv")
sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
sns.distplot(sub_lqt['prediction'], color='pink', bins=100)
# Out:
# /tmp/ipykernel_99675/1927246723.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
# /tmp/ipykernel_99675/1927246723.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sub_lstm = pd.read_csv("/opt/ml/dkt_team/code/dkt/output/submission_each_param_lstm.csv")
sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
sns.distplot(sub_lstm['prediction'], color='pink', bins=100)
# Out:
# /tmp/ipykernel_99675/1235003320.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
# /tmp/ipykernel_99675/1235003320.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sub_lstm_assessmentItemID = pd.read_csv("/opt/ml/dkt_team/code/dkt/output/submission_assessmentItemID_param_lstm.csv")
sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
sns.distplot(sub_lstm_assessmentItemID['prediction'], color='pink', bins=100)
# Out:
# /tmp/ipykernel_99675/2016562293.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
# /tmp/ipykernel_99675/2016562293.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sub_lstmattn = pd.read_csv("/opt/ml/dkt_team/code/dkt/output/submission_each_param_lstmattn.csv")
sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
sns.distplot(sub_lstmattn['prediction'], color='pink', bins=100)
# Out:
# /tmp/ipykernel_99675/2023582289.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
# /tmp/ipykernel_99675/2023582289.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sub_bert = pd.read_csv("/opt/ml/dkt_team/code/dkt/output/submission_each_param_bert.csv")
sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
sns.distplot(sub_bert['prediction'], color='pink', bins=100)
# Out:
# /tmp/ipykernel_99675/3434105367.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sub_top['prediction'], color='skyblue', bins=100)
# /tmp/ipykernel_99675/3434105367.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
